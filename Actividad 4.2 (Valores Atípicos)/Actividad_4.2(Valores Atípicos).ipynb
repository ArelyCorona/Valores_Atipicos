# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('listings_sin_nulos.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3858 entries, 0 to 3857
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    3858 non-null   int64
#  1   host_id                                       3858 non-null   int64
#  2   host_since                                    3858 non-null   object
#  3   host_response_time                            3858 non-null   object
#  4   host_response_rate                            3858 non-null   object
#  5   host_acceptance_rate                          3858 non-null   object
#  6   host_listings_count                           3858 non-null   int64
#  7   host_total_listings_count                     3858 non-null   int64
#  8   host_verifications                            3858 non-null   object
#  9   neighbourhood_cleansed                        3858 non-null   object
#  10  latitude                                      3858 non-null   float64
#  11  longitude                                     3858 non-null   float64
#  12  property_type                                 3858 non-null   object
#  13  room_type                                     3858 non-null   object
#  14  accommodates                                  3858 non-null   int64
#  15  bathrooms                                     3858 non-null   float64
#  16  bathrooms_text                                3858 non-null   object
#  17  bedrooms                                      3858 non-null   float64
#  18  beds                                          3858 non-null   float64
#  19  amenities                                     3858 non-null   object
#  20  price                                         3858 non-null   object
#  21  minimum_nights                                3858 non-null   int64
#  22  maximum_nights                                3858 non-null   int64
#  23  minimum_nights_avg_ntm                        3858 non-null   float64
#  24  maximum_nights_avg_ntm                        3858 non-null   float64
#  25  has_availability                              3858 non-null   object
#  26  availability_30                               3858 non-null   int64
#  27  availability_60                               3858 non-null   int64
#  28  availability_90                               3858 non-null   int64
#  29  availability_365                              3858 non-null   int64
#  30  number_of_reviews                             3858 non-null   int64
#  31  number_of_reviews_ltm                         3858 non-null   int64
#  32  number_of_reviews_l30d                        3858 non-null   int64
#  33  first_review                                  3858 non-null   object
#  34  last_review                                   3858 non-null   object
#  35  review_scores_rating                          3858 non-null   float64
#  36  review_scores_accuracy                        3858 non-null   float64
#  37  review_scores_cleanliness                     3858 non-null   float64
#  38  review_scores_checkin                         3858 non-null   float64
#  39  review_scores_communication                   3858 non-null   float64
#  40  review_scores_location                        3858 non-null   float64
#  41  review_scores_value                           3858 non-null   float64
#  42  instant_bookable                              3858 non-null   object
#  43  calculated_host_listings_count                3858 non-null   int64
#  44  calculated_host_listings_count_entire_homes   3858 non-null   int64
#  45  calculated_host_listings_count_private_rooms  3858 non-null   int64
#  46  calculated_host_listings_count_shared_rooms   3858 non-null   int64
#  47  reviews_per_month                             3858 non-null   float64
# dtypes: float64(15), int64(18), object(15)
# memory usage: 1.4+ MB

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                                      0
# host_id                                         0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# first_review                                    0
# last_review                                     0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
#numeric_columns = "listings_sin_nulos.csv".select_dtypes(include=['number']).columns.tolist()
#numeric_columns



# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("listings_sin_nulos.csv")

# Seleccionar solo las columnas numéricas
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

print(numeric_columns)  # Mostrar nombres de las columnas numéricas
# Out:
# ['Unnamed: 0', 'host_id', 'host_listings_count', 'host_total_listings_count', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
df_numerico = df.select_dtypes(include=['number'])
df_numerico
# Out:
#       Unnamed: 0    host_id  host_listings_count  host_total_listings_count  \
# 0              0     517685                    2                          3
# 1              1     581737                    3                          3
# 2              3     765694                    1                          1
# 3              4     108297                    1                          1
# 4              6     825767                    1                          1
# ...          ...        ...                  ...                        ...
# 3853        7729  574407990                    1                          1
# 3854        7738  593735601                    1                          1
# 3855        7750   29290604                    2                          2
# 3856        7773   25340776                    1                          1
# 3857        7777   69783120                    1                          1
#
#        latitude  longitude  accommodates  bathrooms  bedrooms  beds  ...  \
# 0     48.114920  11.489540             2        1.0       1.0   1.0  ...
# 1     48.120710  11.637580             6        1.0       1.0   1.0  ...
# 2     48.138550  11.465860             2        1.0       1.0   1.0  ...
# 3     48.108140  11.527330             4        1.0       1.0   2.0  ...
# 4     48.149570  11.555070             2        1.0       1.0   1.0  ...
# ...         ...        ...           ...        ...       ...   ...  ...
# 3853  48.110030  11.626330             6        2.0       3.0   4.0  ...
# 3854  48.107478  11.571683             2        1.0       1.0   2.0  ...
# 3855  48.184950  11.509240             1        2.0       1.0   1.0  ...
# 3856  48.138100  11.565150             2        1.0       1.0   1.0  ...
# 3857  48.127640  11.572890             2        1.0       1.0   1.0  ...
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          4.81                   4.90
# 1                          4.95                   4.97
# 2                          4.27                   4.78
# 3                          4.99                   4.99
# 4                          4.91                   4.89
# ...                         ...                    ...
# 3853                       5.00                   5.00
# 3854                       5.00                   5.00
# 3855                       5.00                   4.00
# 3856                       5.00                   5.00
# 3857                       5.00                   5.00
#
#       review_scores_communication  review_scores_location  \
# 0                            4.93                    4.78
# 1                            5.00                    4.66
# 2                            4.80                    4.59
# 3                            4.98                    4.77
# 4                            4.88                    4.82
# ...                           ...                     ...
# 3853                         5.00                    5.00
# 3854                         5.00                    5.00
# 3855                         5.00                    3.00
# 3856                         5.00                    5.00
# 3857                         5.00                    5.00
#
#       review_scores_value  calculated_host_listings_count  \
# 0                    4.73                               2
# 1                    4.61                               3
# 2                    4.44                               1
# 3                    4.91                               1
# 4                    4.79                               1
# ...                   ...                             ...
# 3853                 5.00                               1
# 3854                 5.00                               1
# 3855                 3.00                               2
# 3856                 5.00                               1
# 3857                 5.00                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               3
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 3853                                            1
# 3854                                            1
# 3855                                            0
# 3856                                            1
# 3857                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                1
# 4                                                1
# ...                                            ...
# 3853                                             0
# 3854                                             0
# 3855                                             2
# 3856                                             0
# 3857                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.80
# 1                                               0               0.46
# 2                                               0               0.26
# 3                                               0               3.58
# 4                                               0               0.74
# ...                                           ...                ...
# 3853                                            0               1.00
# 3854                                            0               1.00
# 3855                                            0               1.00
# 3856                                            0               1.00
# 3857                                            0               3.00
#
# [3858 rows x 33 columns]

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                                      0
# host_id                                         0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# first_review                                    0
# last_review                                     0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
# Identificar columnas cuantitativas (numéricas) y cualitativas (categóricas)
cuantitativas = df.select_dtypes(include=['number'])
cualitativas = df.select_dtypes(exclude=['number'])

# %%
cuantitativas
# Out:
#       Unnamed: 0    host_id  host_listings_count  host_total_listings_count  \
# 0              0     517685                    2                          3
# 1              1     581737                    3                          3
# 2              3     765694                    1                          1
# 3              4     108297                    1                          1
# 4              6     825767                    1                          1
# ...          ...        ...                  ...                        ...
# 3853        7729  574407990                    1                          1
# 3854        7738  593735601                    1                          1
# 3855        7750   29290604                    2                          2
# 3856        7773   25340776                    1                          1
# 3857        7777   69783120                    1                          1
#
#        latitude  longitude  accommodates  bathrooms  bedrooms  beds  ...  \
# 0     48.114920  11.489540             2        1.0       1.0   1.0  ...
# 1     48.120710  11.637580             6        1.0       1.0   1.0  ...
# 2     48.138550  11.465860             2        1.0       1.0   1.0  ...
# 3     48.108140  11.527330             4        1.0       1.0   2.0  ...
# 4     48.149570  11.555070             2        1.0       1.0   1.0  ...
# ...         ...        ...           ...        ...       ...   ...  ...
# 3853  48.110030  11.626330             6        2.0       3.0   4.0  ...
# 3854  48.107478  11.571683             2        1.0       1.0   2.0  ...
# 3855  48.184950  11.509240             1        2.0       1.0   1.0  ...
# 3856  48.138100  11.565150             2        1.0       1.0   1.0  ...
# 3857  48.127640  11.572890             2        1.0       1.0   1.0  ...
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          4.81                   4.90
# 1                          4.95                   4.97
# 2                          4.27                   4.78
# 3                          4.99                   4.99
# 4                          4.91                   4.89
# ...                         ...                    ...
# 3853                       5.00                   5.00
# 3854                       5.00                   5.00
# 3855                       5.00                   4.00
# 3856                       5.00                   5.00
# 3857                       5.00                   5.00
#
#       review_scores_communication  review_scores_location  \
# 0                            4.93                    4.78
# 1                            5.00                    4.66
# 2                            4.80                    4.59
# 3                            4.98                    4.77
# 4                            4.88                    4.82
# ...                           ...                     ...
# 3853                         5.00                    5.00
# 3854                         5.00                    5.00
# 3855                         5.00                    3.00
# 3856                         5.00                    5.00
# 3857                         5.00                    5.00
#
#       review_scores_value  calculated_host_listings_count  \
# 0                    4.73                               2
# 1                    4.61                               3
# 2                    4.44                               1
# 3                    4.91                               1
# 4                    4.79                               1
# ...                   ...                             ...
# 3853                 5.00                               1
# 3854                 5.00                               1
# 3855                 3.00                               2
# 3856                 5.00                               1
# 3857                 5.00                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               3
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 3853                                            1
# 3854                                            1
# 3855                                            0
# 3856                                            1
# 3857                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                1
# 4                                                1
# ...                                            ...
# 3853                                             0
# 3854                                             0
# 3855                                             2
# 3856                                             0
# 3857                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.80
# 1                                               0               0.46
# 2                                               0               0.26
# 3                                               0               3.58
# 4                                               0               0.74
# ...                                           ...                ...
# 3853                                            0               1.00
# 3854                                            0               1.00
# 3855                                            0               1.00
# 3856                                            0               1.00
# 3857                                            0               3.00
#
# [3858 rows x 33 columns]

# %%
cualitativas
# Out:
#       host_since  host_response_time host_response_rate host_acceptance_rate  \
# 0     18/04/2011  a few days or more                 0%                   6%
# 1     12/05/2011      within an hour               100%                  99%
# 2     01/07/2011      within an hour               100%                  78%
# 3     14/04/2010  within a few hours               100%                 100%
# 4     16/07/2011      within an hour               100%                  67%
# ...          ...                 ...                ...                  ...
# 3853  26/04/2024  within a few hours               100%                 100%
# 3854  02/08/2024  within a few hours               100%                  50%
# 3855  13/03/2015      within an hour               100%                 100%
# 3856  29/12/2014        within a day               100%                  67%
# 3857  01/05/2016      within an hour               100%                  60%
#
#       host_verifications        neighbourhood_cleansed  \
# 0     ['email', 'phone']                        Hadern
# 1     ['email', 'phone']                  Berg am Laim
# 2     ['email', 'phone']            Pasing-Obermenzing
# 3     ['email', 'phone']             Sendling-Westpark
# 4     ['email', 'phone']                   Maxvorstadt
# ...                  ...                           ...
# 3853           ['phone']            Ramersdorf-Perlach
# 3854  ['email', 'phone']       Untergiesing-Harlaching
# 3855  ['email', 'phone']                       Moosach
# 3856  ['email', 'phone']                Altstadt-Lehel
# 3857  ['email', 'phone']  Ludwigsvorstadt-Isarvorstadt
#
#                     property_type        room_type bathrooms_text  \
# 0              Entire rental unit  Entire home/apt         1 bath
# 1              Entire rental unit  Entire home/apt         1 bath
# 2              Entire rental unit  Entire home/apt         1 bath
# 3            Private room in home     Private room  1 shared bath
# 4     Private room in rental unit     Private room  1 shared bath
# ...                           ...              ...            ...
# 3853                  Entire home  Entire home/apt        2 baths
# 3854           Entire rental unit  Entire home/apt         1 bath
# 3855  Private room in rental unit     Private room        2 baths
# 3856           Entire rental unit  Entire home/apt         1 bath
# 3857           Entire rental unit  Entire home/apt         1 bath
#
#                                               amenities    price  \
# 0     ["Luggage dropoff allowed", "Heating", "Hot wa...   $95.00
# 1     ["Luggage dropoff allowed", "Heating", "Free p...  $145.00
# 2     ["Luggage dropoff allowed", "Outdoor furniture...   $86.00
# 3     ["Luggage dropoff allowed", "Heating", "Paid w...  $120.00
# 4     ["Luggage dropoff allowed", "Heating", "Dishes...  $129.00
# ...                                                 ...      ...
# 3853  ["Outdoor furniture", "Heating", "Hot water ke...  $230.00
# 3854  ["Coffee maker: espresso machine", "Dishes and...  $184.00
# 3855  ["Smoke alarm", "Central heating", "Dedicated ...   $73.00
# 3856  ["Heating", "Hot water kettle", "Dishes and si...  $189.00
# 3857  ["Smoke alarm", "Air conditioning", "Lockbox",...  $178.00
#
#      has_availability first_review last_review instant_bookable
# 0                   t   03/10/2011  03/10/2019                f
# 1                   t   08/07/2011  01/09/2024                f
# 2                   t   15/08/2011  24/07/2024                t
# 3                   t   25/09/2011  18/08/2024                f
# 4                   t   22/05/2012  01/09/2024                f
# ...               ...          ...         ...              ...
# 3853                t   23/09/2024  23/09/2024                f
# 3854                t   22/09/2024  22/09/2024                f
# 3855                t   23/09/2024  23/09/2024                f
# 3856                t   23/09/2024  23/09/2024                f
# 3857                t   17/09/2024  19/09/2024                f
#
# [3858 rows x 15 columns]

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de cada columna del dataframe')
plt.show()

# %%
# Realizamos diagramas de caja o bigote para una columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['host_total_listings_count'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de cada columna del dataframe')
plt.show()

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINACIÓN DE OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos

y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido Unnamed: 0                                      1.025063e+04
# host_id                                         7.792159e+08
# host_listings_count                             1.313525e+02
# host_total_listings_count                       1.603163e+02
# latitude                                        4.821776e+01
# longitude                                       1.172064e+01
# accommodates                                    8.090863e+00
# bathrooms                                       2.307350e+00
# bedrooms                                        4.380972e+00
# beds                                            5.569419e+00
# minimum_nights                                  5.366295e+01
# maximum_nights                                  1.497509e+03
# minimum_nights_avg_ntm                          5.151155e+01
# maximum_nights_avg_ntm                          4.017085e+08
# availability_30                                 3.730750e+01
# availability_60                                 8.530227e+01
# availability_90                                 1.358748e+02
# availability_365                                5.000830e+02
# number_of_reviews                               3.574757e+02
# number_of_reviews_ltm                           1.005257e+02
# number_of_reviews_l30d                          9.555919e+00
# review_scores_rating                            5.882973e+00
# review_scores_accuracy                          5.868631e+00
# review_scores_cleanliness                       6.017098e+00
# review_scores_checkin                           5.809667e+00
# review_scores_communication                     5.820197e+00
# review_scores_location                          5.816450e+00
# review_scores_value                             5.917218e+00
# calculated_host_listings_count                  3.635692e+01
# calculated_host_listings_count_entire_homes     3.568455e+01
# calculated_host_listings_count_private_rooms    5.337199e+00
# calculated_host_listings_count_shared_rooms     5.734811e-01
# reviews_per_month                               7.684324e+00
# dtype: float64
# Límite inferior permitido Unnamed: 0                                     -2.776498e+03
# host_id                                        -3.841577e+08
# host_listings_count                            -1.175059e+02
# host_total_listings_count                      -1.426558e+02
# latitude                                        4.805986e+01
# longitude                                       1.140407e+01
# accommodates                                   -2.375985e+00
# bathrooms                                      -4.322394e-02
# bedrooms                                       -1.943440e+00
# beds                                           -2.222089e+00
# minimum_nights                                 -4.422853e+01
# maximum_nights                                 -8.102260e+02
# minimum_nights_avg_ntm                         -4.167889e+01
# maximum_nights_avg_ntm                         -3.835116e+08
# availability_30                                -1.630179e+01
# availability_60                                -3.394250e+01
# availability_90                                -5.151351e+01
# availability_365                               -2.086170e+02
# number_of_reviews                              -2.737194e+02
# number_of_reviews_ltm                          -7.609805e+01
# number_of_reviews_l30d                         -7.276500e+00
# review_scores_rating                            3.651527e+00
# review_scores_accuracy                          3.719881e+00
# review_scores_cleanliness                       3.422047e+00
# review_scores_checkin                           3.872059e+00
# review_scores_communication                     3.878606e+00
# review_scores_location                          3.717537e+00
# review_scores_value                             3.295089e+00
# calculated_host_listings_count                 -2.870736e+01
# calculated_host_listings_count_entire_homes    -2.961715e+01
# calculated_host_listings_count_private_rooms   -3.809983e+00
# calculated_host_listings_count_shared_rooms    -5.460057e-01
# reviews_per_month                              -4.806081e+00
# dtype: float64

# %%
#Obtenemos datos y los outliers se convierten en nulos en el dataframe
df1=cuantitativas [(y<=Limite_Superior)&(y>=Limite_Inferior)]
df1
# Out:
#       Unnamed: 0    host_id  host_listings_count  host_total_listings_count  \
# 0              0     517685                  2.0                        3.0
# 1              1     581737                  3.0                        3.0
# 2              3     765694                  1.0                        1.0
# 3              4     108297                  1.0                        1.0
# 4              6     825767                  1.0                        1.0
# ...          ...        ...                  ...                        ...
# 3853        7729  574407990                  1.0                        1.0
# 3854        7738  593735601                  1.0                        1.0
# 3855        7750   29290604                  2.0                        2.0
# 3856        7773   25340776                  1.0                        1.0
# 3857        7777   69783120                  1.0                        1.0
#
#        latitude  longitude  accommodates  bathrooms  bedrooms  beds  ...  \
# 0     48.114920  11.489540           2.0        1.0       1.0   1.0  ...
# 1     48.120710  11.637580           6.0        1.0       1.0   1.0  ...
# 2     48.138550  11.465860           2.0        1.0       1.0   1.0  ...
# 3     48.108140  11.527330           4.0        1.0       1.0   2.0  ...
# 4     48.149570  11.555070           2.0        1.0       1.0   1.0  ...
# ...         ...        ...           ...        ...       ...   ...  ...
# 3853  48.110030  11.626330           6.0        2.0       3.0   4.0  ...
# 3854  48.107478  11.571683           2.0        1.0       1.0   2.0  ...
# 3855  48.184950  11.509240           1.0        2.0       1.0   1.0  ...
# 3856  48.138100  11.565150           2.0        1.0       1.0   1.0  ...
# 3857  48.127640  11.572890           2.0        1.0       1.0   1.0  ...
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          4.81                   4.90
# 1                          4.95                   4.97
# 2                          4.27                   4.78
# 3                          4.99                   4.99
# 4                          4.91                   4.89
# ...                         ...                    ...
# 3853                       5.00                   5.00
# 3854                       5.00                   5.00
# 3855                       5.00                   4.00
# 3856                       5.00                   5.00
# 3857                       5.00                   5.00
#
#       review_scores_communication  review_scores_location  \
# 0                            4.93                    4.78
# 1                            5.00                    4.66
# 2                            4.80                    4.59
# 3                            4.98                    4.77
# 4                            4.88                    4.82
# ...                           ...                     ...
# 3853                         5.00                    5.00
# 3854                         5.00                    5.00
# 3855                         5.00                     NaN
# 3856                         5.00                    5.00
# 3857                         5.00                    5.00
#
#       review_scores_value  calculated_host_listings_count  \
# 0                    4.73                             2.0
# 1                    4.61                             3.0
# 2                    4.44                             1.0
# 3                    4.91                             1.0
# 4                    4.79                             1.0
# ...                   ...                             ...
# 3853                 5.00                             1.0
# 3854                 5.00                             1.0
# 3855                  NaN                             2.0
# 3856                 5.00                             1.0
# 3857                 5.00                             1.0
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             2.0
# 1                                             3.0
# 2                                             1.0
# 3                                             0.0
# 4                                             0.0
# ...                                           ...
# 3853                                          1.0
# 3854                                          1.0
# 3855                                          0.0
# 3856                                          1.0
# 3857                                          1.0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              0.0
# 1                                              0.0
# 2                                              0.0
# 3                                              1.0
# 4                                              1.0
# ...                                            ...
# 3853                                           0.0
# 3854                                           0.0
# 3855                                           2.0
# 3856                                           0.0
# 3857                                           0.0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                             0.0               0.80
# 1                                             0.0               0.46
# 2                                             0.0               0.26
# 3                                             0.0               3.58
# 4                                             0.0               0.74
# ...                                           ...                ...
# 3853                                          0.0               1.00
# 3854                                          0.0               1.00
# 3855                                          0.0               1.00
# 3856                                          0.0               1.00
# 3857                                          0.0               3.00
#
# [3858 rows x 33 columns]

# %%
valores_nulos1= df1.isnull().sum()
valores_nulos1
# Out:
# Unnamed: 0                                       0
# host_id                                          0
# host_listings_count                             12
# host_total_listings_count                       12
# latitude                                         8
# longitude                                        2
# accommodates                                    55
# bathrooms                                       78
# bedrooms                                        21
# beds                                            80
# minimum_nights                                  58
# maximum_nights                                   0
# minimum_nights_avg_ntm                          62
# maximum_nights_avg_ntm                          19
# availability_30                                  0
# availability_60                                  0
# availability_90                                  0
# availability_365                                 0
# number_of_reviews                               77
# number_of_reviews_ltm                           34
# number_of_reviews_l30d                          37
# review_scores_rating                            63
# review_scores_accuracy                          70
# review_scores_cleanliness                       83
# review_scores_checkin                           57
# review_scores_communication                     66
# review_scores_location                          66
# review_scores_value                             84
# calculated_host_listings_count                  72
# calculated_host_listings_count_entire_homes     72
# calculated_host_listings_count_private_rooms    88
# calculated_host_listings_count_shared_rooms     28
# reviews_per_month                               50
# dtype: int64

# %%
df_clean=df1.copy()
df_clean=df_clean.fillna(round(df1.mean(),1))
df_clean

valores_nulos=df_clean.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75

y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q1
iqr=percentile75-percentile25

Limite_Superior_iqr=percentile75 + 1.5*iqr
Limite_Inferior_iqr=percentile25 + 1.5*iqr

# %%
#Obtenemos datos limpios del Dataframe

df1_iqr=cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
df1_iqr
# Out:
#       Unnamed: 0      host_id  host_listings_count  host_total_listings_count  \
# 0            NaN          NaN                  NaN                        NaN
# 1            NaN          NaN                  NaN                        NaN
# 2            NaN          NaN                  NaN                        NaN
# 3            NaN          NaN                  NaN                        NaN
# 4            NaN          NaN                  NaN                        NaN
# ...          ...          ...                  ...                        ...
# 3853      7729.0  574407990.0                  NaN                        NaN
# 3854      7738.0  593735601.0                  NaN                        NaN
# 3855      7750.0          NaN                  NaN                        NaN
# 3856      7773.0          NaN                  NaN                        NaN
# 3857      7777.0          NaN                  NaN                        NaN
#
#       latitude  longitude  accommodates  bathrooms  bedrooms  beds  ...  \
# 0          NaN        NaN           NaN        1.0       1.0   NaN  ...
# 1          NaN   11.63758           6.0        1.0       1.0   NaN  ...
# 2          NaN        NaN           NaN        1.0       1.0   NaN  ...
# 3          NaN        NaN           NaN        1.0       1.0   NaN  ...
# 4          NaN        NaN           NaN        1.0       1.0   NaN  ...
# ...        ...        ...           ...        ...       ...   ...  ...
# 3853       NaN   11.62633           6.0        NaN       NaN   NaN  ...
# 3854       NaN        NaN           NaN        1.0       1.0   NaN  ...
# 3855  48.18495        NaN           NaN        NaN       1.0   NaN  ...
# 3856       NaN        NaN           NaN        1.0       1.0   NaN  ...
# 3857       NaN        NaN           NaN        1.0       1.0   NaN  ...
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
# ...                         ...                    ...
# 3853                        NaN                    NaN
# 3854                        NaN                    NaN
# 3855                        NaN                    NaN
# 3856                        NaN                    NaN
# 3857                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
# ...                           ...                     ...
# 3853                          NaN                     NaN
# 3854                          NaN                     NaN
# 3855                          NaN                     NaN
# 3856                          NaN                     NaN
# 3857                          NaN                     NaN
#
#       review_scores_value  calculated_host_listings_count  \
# 0                     NaN                             NaN
# 1                     NaN                             3.0
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# ...                   ...                             ...
# 3853                  NaN                             NaN
# 3854                  NaN                             NaN
# 3855                  NaN                             NaN
# 3856                  NaN                             NaN
# 3857                  NaN                             NaN
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             2.0
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3853                                          NaN
# 3854                                          NaN
# 3855                                          NaN
# 3856                                          NaN
# 3857                                          NaN
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3853                                           NaN
# 3854                                           NaN
# 3855                                           2.0
# 3856                                           NaN
# 3857                                           NaN
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                             0.0                NaN
# 1                                             0.0                NaN
# 2                                             0.0                NaN
# 3                                             0.0               3.58
# 4                                             0.0                NaN
# ...                                           ...                ...
# 3853                                          0.0                NaN
# 3854                                          0.0                NaN
# 3855                                          0.0                NaN
# 3856                                          0.0                NaN
# 3857                                          0.0               3.00
#
# [3858 rows x 33 columns]

# %%
valores_nulos=df1_iqr.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                                      3824
# host_id                                         3656
# host_listings_count                             3515
# host_total_listings_count                       3607
# latitude                                        3443
# longitude                                       3489
# accommodates                                    3515
# bathrooms                                        736
# bedrooms                                         891
# beds                                            3584
# minimum_nights                                  3497
# maximum_nights                                  3778
# minimum_nights_avg_ntm                          3497
# maximum_nights_avg_ntm                          3858
# availability_30                                 3615
# availability_60                                 3858
# availability_90                                 3858
# availability_365                                3829
# number_of_reviews                               3613
# number_of_reviews_ltm                           3546
# number_of_reviews_l30d                          3403
# review_scores_rating                            3858
# review_scores_accuracy                          3858
# review_scores_cleanliness                       3858
# review_scores_checkin                           3858
# review_scores_communication                     3858
# review_scores_location                          3858
# review_scores_value                             3858
# calculated_host_listings_count                  3634
# calculated_host_listings_count_entire_homes     3645
# calculated_host_listings_count_private_rooms    3636
# calculated_host_listings_count_shared_rooms       28
# reviews_per_month                               3509
# dtype: int64

# %%
valores_nulos=df1_iqr.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(112070)

# %%
df_clean_iqr=df1.copy()
df_clean_iqr=df_clean.fillna(round(df1.mean(),1))
df_clean_iqr

valores_nulos=df_clean_iqr.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %%
#Union del dataframe cuantitativo con el cualitativo 

Datos_limpios = pd.concat([cualitativas, df_clean_iqr], axis=1)
Datos_limpios
# Out:
#       host_since  host_response_time host_response_rate host_acceptance_rate  \
# 0     18/04/2011  a few days or more                 0%                   6%
# 1     12/05/2011      within an hour               100%                  99%
# 2     01/07/2011      within an hour               100%                  78%
# 3     14/04/2010  within a few hours               100%                 100%
# 4     16/07/2011      within an hour               100%                  67%
# ...          ...                 ...                ...                  ...
# 3853  26/04/2024  within a few hours               100%                 100%
# 3854  02/08/2024  within a few hours               100%                  50%
# 3855  13/03/2015      within an hour               100%                 100%
# 3856  29/12/2014        within a day               100%                  67%
# 3857  01/05/2016      within an hour               100%                  60%
#
#       host_verifications        neighbourhood_cleansed  \
# 0     ['email', 'phone']                        Hadern
# 1     ['email', 'phone']                  Berg am Laim
# 2     ['email', 'phone']            Pasing-Obermenzing
# 3     ['email', 'phone']             Sendling-Westpark
# 4     ['email', 'phone']                   Maxvorstadt
# ...                  ...                           ...
# 3853           ['phone']            Ramersdorf-Perlach
# 3854  ['email', 'phone']       Untergiesing-Harlaching
# 3855  ['email', 'phone']                       Moosach
# 3856  ['email', 'phone']                Altstadt-Lehel
# 3857  ['email', 'phone']  Ludwigsvorstadt-Isarvorstadt
#
#                     property_type        room_type bathrooms_text  \
# 0              Entire rental unit  Entire home/apt         1 bath
# 1              Entire rental unit  Entire home/apt         1 bath
# 2              Entire rental unit  Entire home/apt         1 bath
# 3            Private room in home     Private room  1 shared bath
# 4     Private room in rental unit     Private room  1 shared bath
# ...                           ...              ...            ...
# 3853                  Entire home  Entire home/apt        2 baths
# 3854           Entire rental unit  Entire home/apt         1 bath
# 3855  Private room in rental unit     Private room        2 baths
# 3856           Entire rental unit  Entire home/apt         1 bath
# 3857           Entire rental unit  Entire home/apt         1 bath
#
#                                               amenities  ...  \
# 0     ["Luggage dropoff allowed", "Heating", "Hot wa...  ...
# 1     ["Luggage dropoff allowed", "Heating", "Free p...  ...
# 2     ["Luggage dropoff allowed", "Outdoor furniture...  ...
# 3     ["Luggage dropoff allowed", "Heating", "Paid w...  ...
# 4     ["Luggage dropoff allowed", "Heating", "Dishes...  ...
# ...                                                 ...  ...
# 3853  ["Outdoor furniture", "Heating", "Hot water ke...  ...
# 3854  ["Coffee maker: espresso machine", "Dishes and...  ...
# 3855  ["Smoke alarm", "Central heating", "Dedicated ...  ...
# 3856  ["Heating", "Hot water kettle", "Dishes and si...  ...
# 3857  ["Smoke alarm", "Air conditioning", "Lockbox",...  ...
#
#      review_scores_cleanliness review_scores_checkin  \
# 0                         4.81                  4.90
# 1                         4.95                  4.97
# 2                         4.27                  4.78
# 3                         4.99                  4.99
# 4                         4.91                  4.89
# ...                        ...                   ...
# 3853                      5.00                  5.00
# 3854                      5.00                  5.00
# 3855                      5.00                  4.00
# 3856                      5.00                  5.00
# 3857                      5.00                  5.00
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.93                   4.78                4.73
# 1                           5.00                   4.66                4.61
# 2                           4.80                   4.59                4.44
# 3                           4.98                   4.77                4.91
# 4                           4.88                   4.82                4.79
# ...                          ...                    ...                 ...
# 3853                        5.00                   5.00                5.00
# 3854                        5.00                   5.00                5.00
# 3855                        5.00                   4.80                4.60
# 3856                        5.00                   5.00                5.00
# 3857                        5.00                   5.00                5.00
#
#       calculated_host_listings_count  \
# 0                                2.0
# 1                                3.0
# 2                                1.0
# 3                                1.0
# 4                                1.0
# ...                              ...
# 3853                             1.0
# 3854                             1.0
# 3855                             2.0
# 3856                             1.0
# 3857                             1.0
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             2.0
# 1                                             3.0
# 2                                             1.0
# 3                                             0.0
# 4                                             0.0
# ...                                           ...
# 3853                                          1.0
# 3854                                          1.0
# 3855                                          0.0
# 3856                                          1.0
# 3857                                          1.0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              0.0
# 1                                              0.0
# 2                                              0.0
# 3                                              1.0
# 4                                              1.0
# ...                                            ...
# 3853                                           0.0
# 3854                                           0.0
# 3855                                           2.0
# 3856                                           0.0
# 3857                                           0.0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                             0.0               0.80
# 1                                             0.0               0.46
# 2                                             0.0               0.26
# 3                                             0.0               3.58
# 4                                             0.0               0.74
# ...                                           ...                ...
# 3853                                          0.0               1.00
# 3854                                          0.0               1.00
# 3855                                          0.0               1.00
# 3856                                          0.0               1.00
# 3857                                          0.0               3.00
#
# [3858 rows x 48 columns]

# %%
Datos_limpios.to_csv('Datos_Limpios_listings_sin_nulos.csv')
